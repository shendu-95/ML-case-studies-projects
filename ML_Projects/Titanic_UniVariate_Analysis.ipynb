# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("C:/Users/shirs/tested.csv")

# %%
df.sample(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 3            895         0       3
# 267         1159         0       3
# 181         1073         0       1
# 338         1230         0       2
# 364         1256         1       1
# 114         1006         1       1
# 299         1191         0       3
# 154         1046         0       3
# 331         1223         0       1
# 160         1052         1       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 267                   Warren, Mr. Charles William    male   NaN      0      0
# 181              Compton, Mr. Alexander Taylor Jr    male  37.0      1      1
# 338                          Denbury, Mr. Herbert    male  25.0      0      0
# 364  Harder, Mrs. George Achilles (Dorothy Annan)  female  25.0      1      0
# 114        Straus, Mrs. Isidor (Rosalie Ida Blun)  female  63.0      1      0
# ...

# %%
df.shape
# Out:
# (418, 12)

# %% [markdown]
# # 1. Categorical Data

# %%
sns.countplot(x = "Survived", data = df, hue = 'Survived')
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    266
# 1    152
# Name: count, dtype: int64

# %%
sns.countplot(x = 'Pclass', data = df, hue = 'Survived')
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
sns.countplot(x='Sex', data=df, hue = 'Sex')
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
df['Sex'].value_counts().plot(kind = 'pie', autopct = '%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
df['Pclass'].value_counts().plot(kind = 'pie', autopct = '%.2f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # 2. Numerical Data

# %%
# Histogram

import matplotlib.pyplot as plt
plt.hist(df['Age'], bins=10)
# Out:
# (array([16., 16., 71., 97., 43., 37., 25., 17.,  9.,  1.]),
#  array([ 0.17 ,  7.753, 15.336, 22.919, 30.502, 38.085, 45.668, 53.251,
#         60.834, 68.417, 76.   ]),
#  <BarContainer object of 10 artists>)

# %%
# Distplot
sns.set_theme()
sns.histplot(df["Age"], kde = True, stat='density', kde_kws=dict(cut=3), alpha = 0.5, edgecolor=(1, 1, 1, 0.4))
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
# Box plot ("5 Number" Summary Minimum, q1, Median, q3, Maximum via IQR. Also includes the outliers)
sns.boxplot(x= df["Age"])
# Out:
# <Axes: xlabel='Age'>

# %%
df['Age'].min()
# Out:
# 0.17

# %%
df['Age'].max()
# Out:
# 76.0
